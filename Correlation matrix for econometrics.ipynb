# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_excel("22222.xlsx")
m = df.corr(method = 'spearman')
plt.figure(figsize = [10,8])
sns.heatmap(m, vmax = 1, vmin = -1,cmap="viridis")
