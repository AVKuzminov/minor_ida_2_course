# %% [markdown]
# <div style="font-size:18pt; padding-top:20px; text-align:center">СЕМИНАР 1. <b>Анализ данных и </b> <span style="font-weight:bold; color:green">Python</span></div><hr>
# <div style="text-align:right;">Папулин С.Ю. <span style="font-style: italic;font-weight: bold;">(papulin_hse@mail.ru)</span></div>

# %% [markdown]
# Заметки:
# 1) Регрессия - предсказание числового по предыдущим. Есть оценка! (крышечка)
# 2) Классификация - отнесение объекта к определенной группе (заранее известным). Нет оценки, все точно более менее
# 3) Кластеризация - разделение на группы (ранее не известных). Сложность в том что нет данных на которых проверять.
# 4) Уменьшение размерности - когда много признаков и нет необходимости все их использовать. Можно их сократить и сделать матрицу меньшей размерности
#
# Этапы:
# 1) Получение исходных данных
# 2) Представление исходных данных
# 3) Разделение полученной выборки на обучающую(70% -80%) и тестирующую (20% - 30%)
# 4) Пострение модели, обучение на обучающей
# 5) Проверка на тестирующей
#
# Волшебное fit

# %% [markdown]
# <a name="0"></a>
# <div><span style="font-size:14pt; font-weight:bold">Содержание</span>
#     <ol>
#         <li><a href="#1">IPython</a></li>
#         <li><a href="#2">NumPy</a>
#         <li><a href="#3">Pandas</a>
#         <li><a href="#4">SymPy</a>
#         <li><a href="#5">Matplotlib</a>
#         <li><a href="#6">SciPy</a>
#         <li><a href="#7">Scikit-learn</a>
#         <li><a href="#8">Источники</a>
#         </li>
#     </ol>
# </div>

# %% [markdown]
# <a name="1"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">1. IPython / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://jupyter.org/">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <div style = "font-size:12pt; text-align:left; font-weight:bold">Основы работы с <span style="color:green">NOTEBOOK</span></div>

# %% [markdown]
# <div style = "color:blue; font-size:12pt;">Colored text line</div>
# <br>
# <div><b>Задание 1.</b> Создать формулу в Notebook </div>
# <br>
# <div>$$c = \sqrt{a^2 + b^2}$$</div>
# <br>
# <div>Формула в строке $cos (2\theta) = \cos^2 \theta - \sin^2 \theta$</div>

# %% [markdown]
# <div>Создание ссылок <a>https://en.wikibooks.org/wiki/LaTeX/Mathematics</a></div>
# <div></div>

# %%
myList = list(range(10))

for el in myList:
    if el % 2 == 0:
        print(el)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# <a name="2"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">2. NumPy / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://www.numpy.org/">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p><b>Подключение пакета</b></p>

# %%
import numpy as np

# %% [markdown]
# <p><b>Массивы значений</b></p>

# %%
b = np.array([[0, 1, 2, 4], [3, 4, 5, 5], [3, 4, 6, 7]])
b
# Out:
# array([[0, 1, 2, 4],
#        [3, 4, 5, 5],
#        [3, 4, 6, 7]])

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (3, 4)

# %% [markdown]
# <div><b>Минимальное значение элемента массива</b></div>

# %%
x = np.array([1, 3, 2])
#Минимальное значение
x.min()
# Out:
# 1

# %%
#Индекс минимального значения
x.argmin()
# Out:
# 0

# %% [markdown]
# <div><b>Скалярное произведение векторов</b></div>

# %%
y = np.array([2, 4, 6])
#Скалярное произведение
np.dot(x, y)
# Out:
# 26

# %% [markdown]
# <div><b>Перемножение матриц</b></div>

# %%
m1 = np.array([[1, 2], [3, 4]])
m2 = np.array([[5, 6], [7, 8]])
np.dot(m1, m2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# <div>Официальная страница <a href = "http://www.numpy.org/">здесь</a></div>
# <div>Дополнительный материал <a href = "http://www.scipy-lectures.org/intro/numpy/index.html">здесь</a></div>

# %% [markdown]
# <a name="3"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">3. Pandas / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://pandas.pydata.org/">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p><b>Подключение пакета</b></p>

# %%
import pandas as pd

# %% [markdown]
# <p><b>Последовательность значений</b></p>

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# <p><b>Создание DataFrame</b></p>

# %%
randMatrix = np.random.randn(12,3)

# %%
dates = pd.date_range('2016', periods=12, freq ='M')
dates
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame(randMatrix, index=dates, columns=['Москва','Нью-Йорк','Лондон'])
df
# Out:
#               Москва  Нью-Йорк    Лондон
# 2016-01-31  0.279364 -0.559774 -0.927203
# 2016-02-29  0.532582 -0.511387 -0.255726
# 2016-03-31 -1.297496 -0.540548 -0.821793
# 2016-04-30  0.227893  0.773803 -2.419812
# 2016-05-31  1.155807 -0.829237  0.138910
# 2016-06-30 -0.753673  1.542382  0.026550
# 2016-07-31 -1.849012  0.222257  0.653501
# 2016-08-31 -1.279199 -0.419836 -0.035928
# 2016-09-30 -0.204680 -0.381817  1.803263
# 2016-10-31  1.416117  0.680715  0.387158
# 2016-11-30 -0.903592  0.655167 -0.998505
# 2016-12-31 -1.056996 -0.034549 -0.318203

# %% [markdown]
# <div>Официальная страница <a href = "http://pandas.pydata.org/">здесь</a></div>
# <div>Дополнительный материал <a href = 'http://pandas.pydata.org/pandas-docs/stable/10min.html'>здесь</a></div>

# %% [markdown]
# <a name="4"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">4. SymPy / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://www.sympy.org/">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p><b>Подключение пакета</b></p>

# %%
from sympy import diff, symbols
from sympy.utilities.lambdify import lambdify

# %%
sym_x = symbols("x")
sym_f = sym_x**2
sym_f
# Out:
# x**2

# %%
sym_df = diff(sym_f, sym_x)
sym_df
# Out:
# 2*x

# %%
f = lambdify(sym_x, sym_df)
x0 = -4
f(x0)
# Out:
# -8

# %%
from sympy import init_printing, latex

# %%
init_printing()

# %%
sym_f, sym_df
# Out:
# ⎛ 2     ⎞
# ⎝x , 2⋅x⎠

# %%
latex(sym_f)
# Out:
# 'x^{2}'

# %% [markdown]
# <a name="5"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">5. Matplotlib / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://matplotlib.org/">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p><b>Подключение пакета</b></p>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline # чтобы графики внутри тетради были а не на новом окне

# %% [markdown]
# <h4>Пример посроения простого графика</h4>

# %%
def f(x):
    return x**2

x = np.arange(-10, 10, 0.1) #создание типо диапазона как линспейс

plt.plot(x, f(x))
plt.grid(True) #чтобы нарисовать

# %%
image = np.random.rand(30, 30)
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()

# %% [markdown]
# <div>Официальная страница <a href = "http://matplotlib.org/index.html">здесь</a></div>
# <div>Дополнительный материал <a href = "http://www.scipy-lectures.org/intro/matplotlib/matplotlib.html">здесь</a></div>

# %% [markdown]
# <a name="6"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">6. SciPy / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://www.scipy.org/scipylib/index.html">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p><b>Подключение пакета</b></p>

# %%
from scipy import optimize

# %% [markdown]
# <h4>Пример градиентного спуска</h4>

# %%
from scipy import optimize

def f2(x):
    return x**2 + 10 * np.sin(x)

x = np.arange(-10, 10, 0.1)

plt.plot(x, f2(x))
plt.grid(True)

# %% [markdown]
# <div>Локальный минимум в районе 3.8, глобальный около -1.3</div>

# %% [markdown]
# <div><b>Алгоритм BFGS</b></div>

# %% [markdown]
# <div>Поиск минимума с $x=0$</div>

# %%
fm1 = optimize.fmin_bfgs(f2, 0)
fm1
# Out:
# Optimization terminated successfully.
#          Current function value: -7.945823
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# array([-1.30644003])

# %%
plt.plot(x, f2(x), '-', fm1[0], f2(fm1[0]),'o', 0, f2(0),'ro')
plt.grid(True)

# %% [markdown]
# <div>Поиск минимума с $x=3$</div>

# %%
fm2 = optimize.fmin_bfgs(f2, 3)
fm2
# Out:
# Optimization terminated successfully.
#          Current function value: 8.315586
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 8
# array([ 3.83746663])

# %%
plt.plot(x, f2(x), '-', fm2[0], f2(fm2[0]),'o', 3, f2(3), 'ro')
plt.grid(True)

# %% [markdown]
# <div>Официальная страница <a href = "http://www.scipy.org/index.html">здесь</a></div>
# <div>Более подробно о scipy можно узнать <a href = 'http://www.scipy-lectures.org/intro/scipy.html'>здесь</a></div>

# %%
from scipy import stats

# %%
mus = [0, -2, 2]
sigmas = [1, 2, 3, 4]

# %%
plt.figure(1, figsize=[15,4])
for j in range(len(mus)):
    plt.subplot(1,3,j+1)
    plt.title("$\mu_"+str(j+1)+" = "+str(mus[j])+"$")
    for i in range(len(sigmas)):
        plt.plot(x, stats.norm.pdf(x, loc=mus[j], scale=sigmas[i]))     
     
    strSt = ["$\sigma_"]*len(sigmas)
    strEnd = ["$"]*len(sigmas)
    
    legs = [strSt[k]+str(k+1)+"="+str(sigmas[k])+strEnd[k] for k in range(len(sigmas))]

    plt.legend(legs, loc="upper right")
    plt.grid(True)

plt.show()

# %% [markdown]
# <a name="7"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">7. Scikit-learn / <span style="font-style:normal; font-weight:normal; font-size: 14px;"><a href="http://scikit-learn.org/">Официальная страница</a> </div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p><b>Подключение пакета</b></p>

# %%
from sklearn import linear_model
from sklearn.datasets import make_classification

# %%
from matplotlib.colors import ListedColormap

# %% [markdown]
# <p><b>Исходные данные</b></p>

# %%
n = 100
x, y = make_classification(n_samples=n, n_features=2, n_redundant=0, 
                           n_informative=2, n_clusters_per_class=1, n_classes=3, class_sep=1,
                           random_state=1234)

# %%
clrMap = ListedColormap(["blue", "red", "green"])
plt.scatter(x[:,0], x[:,1], c=y, cmap=clrMap)
plt.grid(True)
plt.show()

# %% [markdown]
# <p><b>Формирование обучающего и тестового подмножеств</b></p>

# %%
tr_pr = 0.7
tr_n = int(np.round(tr_pr*n))

x_train = x[:tr_n]
x_test = x[tr_n:]

y_train = y[:tr_n]
y_test = y[tr_n:]

# %% [markdown]
# <p><b>Обучение</b></p>

# %%
logRegMultClass = linear_model.LogisticRegression(penalty="l2", fit_intercept=True, max_iter=100, C=1e5, 
                                         solver="lbfgs", multi_class="ovr", random_state=12345)

# %%
logRegMultClass.fit(x_train, y_train)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=12345,
#           solver='lbfgs', tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# <p><b>Проверка на тестовом подмножестве</b></p>

# %%
score = logRegMultClass.score(x_test, y_test)
score
# Out:
# 0.833333333333

# %% [markdown]
# <p><b>Графики</b></p>

# %%
step = 0.01
xx, yy = np.meshgrid(np.arange(x[:,0].min()-1, x[:,0].max()+1, step), np.arange(x[:,1].min()-1, x[:,1].max()+1, step))
points = np.c_[xx.ravel(), yy.ravel()]
Z = logRegMultClass.predict(points)
Z = Z.reshape(xx.shape)

# %%
plt.figure(1, figsize=[12, 4])

plt.subplot(1,2,1)
plt.title("Train data")
plt.contourf(xx, yy, Z, cmap=clrMap, alpha=.5)
plt.scatter(x_train[:,0], x_train[:,1], c=y_train, s=80, cmap=clrMap, alpha=0.5)
plt.scatter(x_train[:, 0], x_train[:, 1], c=logRegMultClass.predict(x_train), s=20, cmap=clrMap)
plt.grid(True)

plt.subplot(1,2,2)
plt.title("Test data")
plt.contourf(xx, yy, Z, cmap=clrMap, alpha=.5)
plt.scatter(x_test[:,0], x_test[:,1], c=y_test, s=80, cmap=clrMap, alpha=0.5)
plt.scatter(x_test[:,0], x_test[:,1], c=logRegMultClass.predict(x_test), s=20, cmap=clrMap)
plt.grid(True)

plt.show()
